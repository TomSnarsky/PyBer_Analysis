# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
temp = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]
scoop_price = [1.50, 1.60, 1.25, 1.65, 2.10, 2.15, 1.85, 1.75, 1.50, 2.00, 2.25, 2.50]

x_axis = np.arange(len(temp))

# %%
# Tell matplotlib to create a scatter plot based upon the above data

plt.scatter(temp, sales, marker="o", facecolors="red", edgecolors="black", s=np.multiply(scoop_price,20), alpha=0.75)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Set the upper and lower limits of our y axis

plt.ylim(100,630)
# Out:
# (100.0, 630.0)

# %%
# Set the upper and lower limits of our x axis

plt.xlim(10,26)
# Out:
# (10.0, 26.0)

# %%
# Create a title, x label, and y label for our chart

plt.title("Ice Cream Sales vs. Temperature")
plt.xlabel("Temperature (°C)")
plt.ylabel("Sales (Dollars)")
# Out:
# Text(76.56944444444443, 0.5, 'Sales (Dollars)')

# %%
# Save an image of the chart and print to screen

plt.savefig("icecreamchart.png")
plt.show()

# NOTE: If your plot shrinks after saving an image,
# update matplotlib to 2.2 or higher,
# or simply run the above cells again.

# %%
# Create a line of best fit and add it to the graph

m, b = np.polyfit(temp, sales, 1)
plt.plot(x_axis, np.multiply(temp+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/d9/1rglkp5x1n3bt5gwy2pl2cxm0000gn/T/ipykernel_51245/2580278436.py in <module>
#       2
#       3 m, b = np.polyfit(temp, sales, 1)
# ----> 4 plt.plot(temp, m*temp+b)
#
# TypeError: can't multiply sequence by non-int of type 'numpy.float64'
